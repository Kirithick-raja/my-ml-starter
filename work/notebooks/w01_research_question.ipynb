# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirithick-raja/my-ml-starter/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
Lane: AI referral opportunities
Question: Can we accurately identify and rank which content pieces have the highest potential to capture AI-generated search referral traffic (tracked via metrics like ai_sessions_90d and ai_traffic_pct), and what specific content characteristics correlate most strongly with AI visibility?

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
This work aims to improve strategic content investment decisions by identifying which content characteristics effectively attract AI-generated search referral traffic. The content strategy team, alongside SEO and marketing specialists, will act on these insights. A wrong recommendation could lead to misallocated resources, decreased content ROI, and missed opportunities to capture a growing share of AI-driven search visibility, ultimately impacting audience engagement and revenue.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter CSV. Assuming 'california_housing_train.csv' as a relevant sample.
# If a different CSV is intended, please specify its path.
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# Display the first few rows (real numbers)
print("First 5 rows of the dataset:")
display(df.head())

# Display the number of rows and columns
print(f"\nDataset shape (rows, columns): {df.shape}")

# Display basic descriptive statistics for a numerical column
print("\nDescriptive statistics for 'median_income' column:")
display(df['median_income'].describe())
# Out:
# First 5 rows of the dataset:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# Dataset shape (rows, columns): (17000, 9)
#
# Descriptive statistics for 'median_income' column:
# count    17000.000000
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
This work will provide observed and directional insights into the correlation between content characteristics and AI-generated search referral traffic. It aims to offer decision-support by identifying content patterns that tend to perform well under AI visibility metrics (e.g., `ai_sessions_90d`, `ai_traffic_pct`).

However, this analysis will **not** be able to establish causal proof (i.e., that a specific content characteristic directly causes an increase in AI referral traffic). Nor will it be able to 'predict Google' or other AI search algorithms; rather, it will reflect their observed behavior based on available data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
